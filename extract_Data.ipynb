# %%
import pandas as pd
import requests
from datetime import datetime

# %%
url = "https://arbeitnow.com/api/job-board-api"

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

data = response.json()

type(data)
# Out:
# dict

# %%
dataF = data['data']
df = pd.DataFrame(dataF)
df
# Out:
#                                                  slug  \
# 0   coordinator-retailmarketing-mit-teamleadfunkti...
# 1       specialist-digital-marketing-dusseldorf-18365
# 2                      product-manager-cologne-177646
# 3      produktionsleiter-ebersbach-an-der-fils-376867
# 4   java-angular-full-stack-softwareentwickler-dus...
# ..                                                ...
# 95  2400-2600eur-500eur-bonus-telefonische-kundenb...
# 96                            teamleiter-berlin-65052
# 97  system-engineer-requirement-bmw-projekt-munich...
# 98  2400eur-telefonische-kundenbetreuer-mo-fr-buro...
# 99                  business-controller-telgte-374867
#
#                                         company_name  \
# 0                                    Sterntaler GmbH
# 1                                     Kloepfel Group
# 2                                   Bank-Verlag GmbH
# 3                           starmix/Electrostar GmbH
# 4   Intercon Solutions GmbH IT & Engineering Experts
# ..                                               ...
# 95            W&W Human Resources -  Ivonne Wresch -
# 96            W&W Human Resources -  Ivonne Wresch -
# 97                                     univativ GmbH
# 98            W&W Human Resources -  Ivonne Wresch -
# 99                              hygi.de GmbH & Co.KG
#
#                                                 title  \
# 0   Coordinator Retailmarketing  mit Teamleadfunkt...
# 1                Specialist Digital-Marketing (w/m/d)
# 2                             Product Manager (m/w/d)
# 3                           Produktionsleiter (m/w/d)
# 4   Java/Angular Full Stack Softwareentwickler (m/...
# ..                                                ...
# 95  2400-2600€ + 500€ Bonus Telefonische Kundenbet...
# 96                                   Teamleiter m/w/d
# 97    System Engineer Requirement (m/w/d) BMW Projekt
# 98  2400€ Telefonische Kundenbetreuer m/w/d Mo-Fr ...
# 99                        Business Controller (m/w/d)
#
#                                           description  remote  \
# 0   <p><strong>Sterntaler, als Unternehmen und Mar...   False
# 1   <p><strong>Wir suchen Macher!</strong> Gestalt...   False
# 2   <p>Der Bank-Verlag ist das Service-Unternehmen...   False
# 3   <p><strong>Begleite unsere Stars von Morgen.</...   False
# 4   <p><em>Willkommen im Zentrum der Innovation!</...   False
# ..                                                ...     ...
# 95  <p>Möchte Sie für ein internationales Unterneh...   False
# 96  <p>Suchen Sie eine neue Tätigkeit als Teamleit...   False
# 97  <p><strong>Baldmöglichst, Langfristig, mit Opt...   False
# 98  <p>Wollen Sie Teil des 20-köpfiges Teams im Ku...   False
# 99  <p>hygi. de ist einer der führenden Online-Sho...   False
#
#                                                   url  \
# 0   https://www.arbeitnow.com/jobs/companies/stern...
# 1   https://www.arbeitnow.com/jobs/companies/kloep...
# 2   https://www.arbeitnow.com/jobs/companies/bank-...
# 3   https://www.arbeitnow.com/jobs/companies/starm...
# 4   https://www.arbeitnow.com/jobs/companies/inter...
# ..                                                ...
# 95  https://www.arbeitnow.com/jobs/companies/ww-hu...
# 96  https://www.arbeitnow.com/jobs/companies/ww-hu...
# 97  https://www.arbeitnow.com/jobs/companies/univa...
# 98  https://www.arbeitnow.com/jobs/companies/ww-hu...
# 99  https://www.arbeitnow.com/jobs/companies/hygid...
#
#                              tags         job_types               location  \
# 0   [Marketing and Communication]                []               Dornburg
# 1   [Marketing and Communication]                []             Düsseldorf
# 2            [Product Management]  [berufserfahren]                Cologne
# 3                   [Engineering]                []  Ebersbach an der Fils
# 4                            [IT]                []             Düsseldorf
# ..                            ...               ...                    ...
# 95             [Customer Service]                []                 Berlin
# 96      [Management, Team Leader]                []                 Berlin
# 97                  [Engineering]                []                 Munich
# 98             [Customer Service]                []                 Berlin
# 99                  [Controlling]  [berufserfahren]                 Telgte
#
#     created_at
# 0   1709725743
# 1   1709725743
# 2   1709725743
# 3   1709725743
# 4   1709725743
# ..         ...
# 95  1709718544
# 96  1709718544
# 97  1709718544
# 98  1709718544
# 99  1709718544
#
# [100 rows x 10 columns]

# %%
df['tags'] = df['tags'].apply(lambda x: ", ".join(x))

df['tags']
# Out:
# 0     Marketing and Communication
# 1     Marketing and Communication
# 2              Product Management
# 3                     Engineering
# 4                              IT
#                  ...
# 95               Customer Service
# 96        Management, Team Leader
# 97                    Engineering
# 98               Customer Service
# 99                    Controlling
# Name: tags, Length: 100, dtype: object

# %%
df['job_types'] = df['job_types'].apply(lambda x: ", ".join(x))
df['job_types']
# Out:
# 0
# 1
# 2     berufserfahren
# 3
# 4
#            ...
# 95
# 96
# 97
# 98
# 99    berufserfahren
# Name: job_types, Length: 100, dtype: object

# %%
df['created_at'] = df['created_at'].apply(datetime.fromtimestamp)
df['created_at']
# Out:
# 0    2024-03-06 13:49:03
# 1    2024-03-06 13:49:03
# 2    2024-03-06 13:49:03
# 3    2024-03-06 13:49:03
# 4    2024-03-06 13:49:03
#              ...
# 95   2024-03-06 11:49:04
# 96   2024-03-06 11:49:04
# 97   2024-03-06 11:49:04
# 98   2024-03-06 11:49:04
# 99   2024-03-06 11:49:04
# Name: created_at, Length: 100, dtype: datetime64[ns]

# %%
df.to_excel("jobs.xlsx")
